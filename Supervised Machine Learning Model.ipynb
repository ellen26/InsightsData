# %%
#import data
from matplotlib import pyplot as plt
import numpy as np
import math #needed for definition of pi
import pandas as pd
df = pd.read_excel(r'C:\Users\xwang\OneDrive - CCMI\Desktop\Python\New folder\Honolulu.xlsx', sheet_name = 'Sheet2')
print (df)
# Out:
#          Time  Total Construction Volume
# 0  2016-01-01                4333.932589
# 1  2016-04-01                3424.301109
# 2  2016-07-01                4361.771978
# 3  2016-10-01                3758.132530
# 4  2017-01-01                3668.364822
# 5  2017-04-01                3566.123587
# 6  2017-07-01                4482.269183
# 7  2017-10-01                4099.037485
# 8  2018-01-01                4984.994960
# 9  2018-04-01                4818.850181
# 10 2018-07-01                3982.529082
# 11 2018-10-01                4011.014984
# 12 2019-01-01                3685.682817
# 13 2019-04-01                3787.764595
# 14 2019-07-01                3438.265745
# 15 2019-10-01                3860.097380
# 16 2020-01-01                3551.416972
# 17 2020-04-01                3405.185646
# 18 2020-07-01                3008.326093
# 19 2020-10-01                3281.224681
# 20 2021-01-01                3804.058446
# 21 2021-04-01                4121.902260
# ...

# %%
x = df['Time']
y = df['Total Construction Volume']

# %%
#plot trend of data - reason why the simple predictive model will not work
plt.plot(x,y)
plt.xlabel("Time")
plt.ylabel("Total Construction Volume")
plt.title('Trend over years')
plt.show()

# %%
#https://medium.com/@cdabakoglu/time-series-forecasting-arima-lstm-prophet-with-python-e73a750a9887

# %%
#ML method to split into train and test set
train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

# %%
plt.scatter(train_x, train_y)
plt.show()
